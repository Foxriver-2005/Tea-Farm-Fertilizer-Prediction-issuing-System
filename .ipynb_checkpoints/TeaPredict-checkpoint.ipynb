# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv('TeaDataset.csv')
dataset
# Out:
#      bushes  kilos  size  fertilizer
# 0       500    900   2.0           1
# 1       600   1080   3.0           1
# 2       700   1260   5.0           1
# 3       800   1440   5.0           1
# 4       900   1620   5.0           1
# ..      ...    ...   ...         ...
# 127   13200  23100   8.0          10
# 128   13300  23275   9.0          11
# 129   13400  23450  10.0          12
# 130   13500  23625   8.0          13
# 131   13600  23800   6.0          14
#
# [132 rows x 4 columns]

# %%
dataset.corr()['fertilizer']
dataset.corr()['fertilizer']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12932\1491758219.py in <module>
#       1 dataset.corr()['fertilizer']
# ----> 2 dataset.corrcoef()['fertilizer']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'corrcoef'

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset['bushes'],dataset['fertilizer'])
plt.xlabel('bushes')
plt.ylabel('fertilizer')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset['kilos'],dataset['fertilizer'])
plt.xlabel('kilos')
plt.ylabel('fertilizer')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset['size'],dataset['fertilizer'])
plt.xlabel('size')
plt.ylabel('fertilizer')
plt.show()

# %%
dataset_np = dataset.to_numpy()
dataset_np.shape
# Out:
# (132, 4)

# %%
X_train, Y_train = dataset_np[:,:3],dataset_np[:,-1]
X_train.shape,Y_train.shape
# Out:
# ((132, 3), (132,))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(X_train,Y_train)
prediction = model.predict(X_train)
prediction


import pickle
with open('LinearRegression.pkl','wb') as file:
    pickle.dump(model, file)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mean_absolute_error(prediction,Y_train),mean_squared_error(prediction,Y_train)
# Out:
# (0.9930296804854014, 1.9732395749519542)

# %%
prediction_df = pd.DataFrame({'Bushes':dataset['bushes'],
                             'Kilos': dataset['kilos'],
                             'Size' : dataset['size'],
                             'Actual Fertilizers': dataset['fertilizer'],
                             'Model Prediction of Fertlizer': prediction})
prediction_df
# Out:
#      Bushes  Kilos  Size  Actual Fertilizers  Model Prediction of Fertlizer
# 0       500    900   2.0                   1                       0.404675
# 1       600   1080   3.0                   1                       0.907211
# 2       700   1260   5.0                   1                       1.875667
# 3       800   1440   5.0                   1                       1.912283
# 4       900   1620   5.0                   1                       1.948899
# ..      ...    ...   ...                 ...                            ...
# 127   13200  23100   8.0                  10                       7.740536
# 128   13300  23275   9.0                  11                       8.242239
# 129   13400  23450  10.0                  12                       8.743943
# 130   13500  23625   8.0                  13                       7.847886
# 131   13600  23800   6.0                  14                       6.951829
#
# [132 rows x 5 columns]
